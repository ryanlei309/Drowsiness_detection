# %% [markdown]
# 登入Google Drive，並且取得路徑

# %%
from google.colab import drive
import os

drive.mount('/content/drive', force_remount=True)

FOLDERNAME = 'Colab\ Notebooks/Project/Drowsiness_detection/Drowsiness_detection/'  #請輸入資料夾之所在位置

import sys
sys.path.append('/content/drive/MyDrive/{}'.format(FOLDERNAME))

# %cd drive/MyDrive/$FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/Project/Drowsiness_detection/Drowsiness_detection

# %% [markdown]
# Import 相關資料

# %%
# !{sys.executable} -m pip install pygame   # 安裝pygame，必要程序。

# %% [markdown]
# 載入主程式

# %%
# %run -i 'drowsiness_detection.py'   # 執行程式
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /content/drive/MyDrive/Colab Notebooks/Project/Drowsiness_detection/Drowsiness_detection/drowsiness_detection.py in <module>()
#     232     img_name = str(terms)+".jpg"
#     233
# --> 234     js_reply = video_frame(label_html, bbox)  # 使用webcam
#     235     if not js_reply:
#     236         break
#
# /content/drive/MyDrive/Colab Notebooks/Project/Drowsiness_detection/Drowsiness_detection/drowsiness_detection.py in video_frame(label, bbox)
#     189 # 建立影像框，return data
#     190 def video_frame(label, bbox):
# --> 191   data = eval_js('stream_frame("{}", "{}")'.format(label, bbox))
#     192   return data
#     193
#
# /usr/local/lib/python3.7/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result, timeout_sec)
#      38   if ignore_result:
#      39     return
# ...
