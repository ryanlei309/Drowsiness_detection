# %%
# 呼叫Google gpu 權限
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# 輸入 drowsiness_detection 資料夾之所在位置
FOLDERNAME = 'Colab\ Notebooks/Project/Drowsiness_detection/Drowsiness_detection'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# 把 droswiness_detection資料夾放到虛擬環境
import sys
sys.path.append('/content/drive/MyDrive/{}'.format(FOLDERNAME))
# %cd drive/MyDrive/$FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/Project/Drowsiness_detection/Drowsiness_detection

# %%
# %run -i 'model.py'
